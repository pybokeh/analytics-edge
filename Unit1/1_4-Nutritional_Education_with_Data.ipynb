# %%
import pandas as pd

# %%
df = pd.read_csv('data/USDA.csv')

# %%
df.head()
# Out:
#      ID               Description  Calories  Protein  TotalFat  Carbohydrate  \
# 0  1001          BUTTER,WITH SALT     717.0     0.85     81.11          0.06
# 1  1002  BUTTER,WHIPPED,WITH SALT     717.0     0.85     81.11          0.06
# 2  1003      BUTTER OIL,ANHYDROUS     876.0     0.28     99.48          0.00
# 3  1004               CHEESE,BLUE     353.0    21.40     28.74          2.34
# 4  1005              CHEESE,BRICK     371.0    23.24     29.68          2.79
#
#    Sodium  SaturatedFat  Cholesterol  Sugar  Calcium  Iron  Potassium  \
# 0   714.0        51.368        215.0   0.06     24.0  0.02       24.0
# 1   827.0        50.489        219.0   0.06     24.0  0.16       26.0
# 2     2.0        61.924        256.0   0.00      4.0  0.00        5.0
# 3  1395.0        18.669         75.0   0.50    528.0  0.31      256.0
# 4   560.0        18.764         94.0   0.51    674.0  0.43      136.0
#
#    VitaminC  VitaminE  VitaminD
# 0       0.0      2.32       1.5
# ...

# %%
df.dtypes
# Out:
# ID                int64
# Description      object
# Calories        float64
# Protein         float64
# TotalFat        float64
# Carbohydrate    float64
# Sodium          float64
# SaturatedFat    float64
# Cholesterol     float64
# Sugar           float64
# Calcium         float64
# Iron            float64
# Potassium       float64
# VitaminC        float64
# VitaminE        float64
# VitaminD        float64
# dtype: object

# %%
df.shape
# Out:
# (7058, 16)

# %%
df.describe().transpose()
# Out:
#                count          mean          std     min       25%        50%  \
# ID            7058.0  14259.821196  8577.179705  1001.0  8387.250  13293.500
# Calories      7057.0    219.695338   172.198755     0.0    85.000    181.000
# Protein       7057.0     11.710368    10.919356     0.0     2.290      8.200
# TotalFat      7057.0     10.320614    16.814191     0.0     0.720      4.370
# Carbohydrate  7057.0     20.697860    27.630443     0.0     0.000      7.130
# Sodium        6974.0    322.059220  1045.416931     0.0    37.000     79.000
# SaturatedFat  6757.0      3.452267     6.921267     0.0     0.172      1.256
# Cholesterol   6770.0     41.551994   122.963028     0.0     0.000      3.000
# Sugar         5148.0      8.256540    15.361509     0.0     0.000      1.395
# Calcium       6922.0     73.530627   222.445338     0.0     9.000     19.000
# Iron          6935.0      2.828368     6.019878     0.0     0.520      1.330
# ...

# %% [markdown]
# #### Q: Which food has the highest sodium content?

# %%
df.Sodium.max()
# Out:
# 38758.0

# %%
df.query("Sodium == 38758").loc[:, 'Description']
# Out:
# 264    SALT,TABLE
# Name: Description, dtype: object

# %% [markdown]
# #### A: Table Salt

# %% [markdown]
# #### Q: Which foods and how many foods have a sodium content > 10,000 mg?

# %%
df.query("Sodium > 10000")
# Out:
#          ID                                        Description  Calories  \
# 264    2047                                         SALT,TABLE       0.0
# 921    6075                  SOUP,BF BROTH OR BOUILLON,PDR,DRY     213.0
# 922    6076                          SOUP,BEEF BROTH,CUBED,DRY     170.0
# 924    6080                   SOUP,CHICK BROTH OR BOUILLON,DRY     267.0
# 925    6081                         SOUP,CHICK BROTH CUBES,DRY     198.0
# 937    6115                                   GRAVY,AU JUS,DRY     313.0
# 1302   6979                                       ADOBO FRESCO     271.0
# 5320  18369  LEAVENING AGENTS,BAKING PDR,DOUBLE-ACTING,NA A...      53.0
# 5323  18372                       LEAVENING AGENTS,BAKING SODA       0.0
# 5697  19225                    DESSERTS,RENNIN,TABLETS,UNSWTND      84.0
#
#       Protein  TotalFat  Carbohydrate   Sodium  SaturatedFat  Cholesterol  \
# 264      0.00      0.00          0.00  38758.0         0.000          0.0
# ...

# %%
df.query("Sodium > 10000").shape
# Out:
# (10, 16)
